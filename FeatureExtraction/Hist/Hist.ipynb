# %%
try:
    import google.colab
    google.colab.drive.mount('/content/drive/')
    # %cd ../content/drive/Othercomputers/Laptop/Flood_Detection
except:
    pass

# %%
import sys; 
sys.path.append('../../')
from DataPreparation.DataPreparation import read_data
from FeatureExtraction.Hist.Hist import apply_hist

# %% [markdown]
# ### Data Preparation

# %%
x_train_d, x_val_d, y_train_d, y_val_d = read_data(gray=False)
# Out:
# 100%|██████████| 461/461 [00:10<00:00, 43.70it/s]
# 100%|██████████| 461/461 [00:51<00:00,  8.93it/s]
# x_train shape:  (737, 256, 256, 3)
# x_val shape:  (185, 256, 256, 3)

# %% [markdown]
# ### Feature Extraction

# %%
x_train_f, x_val_f = apply_hist(x_train_d, x_val_d, n_bins=20, saved=False)
