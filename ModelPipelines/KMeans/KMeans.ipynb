# %% [markdown]
# ## Assumptions
# - Water is blue or red (muddy)
# - All what we have is colors

# %%
import sys; sys.path.append('../../')
import numpy as np
import cv2
import matplotlib.pyplot as plt
from DataPreparation.DataPreparation import read_data
from sklearn.cluster import KMeans

# %%
x_train_d, _, _, _ = read_data(normalize=False, new_size=256, transpose=False, saved=True)
# Out:
# x_train shape:  (737, 256, 256, 3)
# x_val shape:  (185, 256, 256, 3)

# %%
from KMeans import get_img, show_img, preprocess_img, cluster, get_mask, water_mask, show_case, save_water


save_water('../../../DataFiles/flooded/0.jpg')
# Out:
# 8
# [[[128 114 161]]] [[[ 66 201 220]]] [[[125 188 155]]] [[[103 249 255]]] [[[ 51 172 219]]] [[[ 94  49 178]]] [[[ 10 161 138]]] [[[ 65 251 194]]]

# %%
show_case( get_img(0, x_train_d))
show_case( get_img(5, x_train_d))
show_case( get_img(10, x_train_d))
show_case( get_img(61, x_train_d))
show_case( get_img(80, x_train_d))
show_case( get_img(71, x_train_d))
show_case( get_img(91, x_train_d))
show_case( get_img(21, x_train_d))
show_case( get_img(23, x_train_d))
show_case( get_img(40, x_train_d))
# Out:
# 7
# (256, 256, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[111  19 133]]] [[[78 19 68]]] [[[150   3 162]]] [[[109  25 112]]] [[[ 17  25 213]]] [[[109  14 148]]] [[[50 31 50]]] [[[108  33  92]]]
# 5
# (256, 256, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[ 24  26 207]]] [[[68 41 68]]] [[[ 33  17 163]]] [[[18 61 96]]] [[[64 81 44]]] [[[ 21  66 116]]] [[[101  80 108]]] [[[ 90  22 126]]]
# 7
# (256, 256, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[101  13 159]]] [[[73 24 73]]] [[[108   7 179]]] [[[102  34 128]]] [[[103  25 144]]] [[[70 57 54]]] [[[110   7 208]]] [[[92 34 98]]]
# 8
# (256, 256, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
