# %%
try:
    import google.colab
    google.colab.drive.mount('/content/drive/')
    # %cd ../content/drive/Othercomputers/Laptop/Flood_Detection/DataPreparation
except:
    pass

# %%
import sys
import numpy as np
from DataPreparation import read_data, visualize_data

# %% [markdown]
# ### Reading & Preprocessing

# %%
x_train_d, x_val_d, y_train_d, y_val_d = read_data()
# Out:
#  43%|████▎     | 197/461 [00:03<00:04, 59.56it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/essam/Documents/GitHub/SI-Project/Flood_Detection/DataPreparation/DataPreparation.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/essam/Documents/GitHub/SI-Project/Flood_Detection/DataPreparation/DataPreparation.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> x_train_d, x_val_d, y_train_d, y_val_d = read_data()
#
# File ~/Documents/GitHub/SI-Project/Flood_Detection/DataPreparation/DataPreparation.py:40, in read_data(gray, new_size, normalize, more_transforms, saved)
#      37 for filename in tqdm(sorted(glob.glob(flooded_path))):
#      38     try:
#      39          # read in RGB
# ---> 40         img = cv2.imread(filename, 0 if gray else cv2.COLOR_BGR2RGB)
#      41         img_p = preprocess_img(img, new_size, normalize, more_transforms)
#      42         x_data.append(img_p)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualization

# %%
visualize_data(x_val_d, y_val_d, height=5, width=7)
