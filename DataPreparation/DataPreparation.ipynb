# %%
try:
    import google.colab
    google.colab.drive.mount('/content/drive/')
    # %cd ../content/drive/Othercomputers/Laptop/Flood_Detection/DataPreparation
except:
    pass
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# [Errno 2] No such file or directory: '../content/drive/Othercomputers/Laptop/Flood_Detection/DataPreparation'
# /content/drive/Othercomputers/Laptop/Flood_Detection/DataPreparation

# %%
import sys
import numpy as np
from DataPreparation import read_data, visualize_data

# %% [markdown]
# ### Reading & Preprocessing

# %%
x_train_d, x_val_d, y_train_d, y_val_d = read_data()
# Out:
# 100%|██████████| 461/461 [00:13<00:00, 33.33it/s]
# 100%|██████████| 461/461 [01:08<00:00,  6.75it/s]
# x_train shape:  (737, 256, 256, 3)
# x_val shape:  (185, 256, 256, 3)

# %% [markdown]
# ### Visualization

# %%
visualize_data(x_val_d, y_val_d, height=5, width=7)
