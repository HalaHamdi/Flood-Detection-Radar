# %%
import numpy as np
from DataPreparation import read_data, visualize_data

# %% [markdown]
# #### Reading & Preprocessing

# %%
x_train_d, x_val_d, y_train_d, y_val_d = read_data(gray=False)
# Out:
# 100%|██████████| 461/461 [00:06<00:00, 73.09it/s]
# 100%|██████████| 461/461 [00:31<00:00, 14.82it/s]
# x_train shape:  (737, 256, 256, 3)
# x_val shape:  (185, 256, 256, 3)

# %% [markdown]
# #### Visualization

# %%
visualize_data(x_val_d, y_val_d, height=5, width=7)
