# %%
try:
    import google.colab
    google.colab.drive.mount('/content/drive/')
    # %cd ../content/drive/Othercomputers/Laptop/Flood_Detection/DataPreparation
except:
    pass

# %%
import sys
import numpy as np
from DataPreparation import read_data, visualize_data, read_sample

# %% [markdown]
# ### Reading & Preprocessing

# %%
x_train_d, x_val_d, y_train_d, y_val_d = read_data(saved=True)
# Out:
# x_train shape:  (737,)
# x_val shape:  (185,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/essam/Documents/GitHub/SI-Project/Flood_Detection/DataPreparation/DataPreparation.ipynb Cell 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/essam/Documents/GitHub/SI-Project/Flood_Detection/DataPreparation/DataPreparation.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> x_train_d, x_val_d, y_train_d, y_val_d = read_data(saved=True)
# ----> <a href='vscode-notebook-cell:/Users/essam/Documents/GitHub/SI-Project/Flood_Detection/DataPreparation/DataPreparation.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> x_sample = read_sample()
#
# TypeError: read_sample() missing 1 required positional argument: 'sample_path'

# %% [markdown]
# ### Visualization

# %%
visualize_data(x_val_d, y_val_d, height=5, width=7)
